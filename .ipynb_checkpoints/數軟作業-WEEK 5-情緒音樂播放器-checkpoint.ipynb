# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

from IPython.display import YouTubeVideo,HTML
import time
from urllib.request import urlopen

# %%
e=e=input('今天心情如何？')
site=()
if ("開心"or"嗨"or"高興"or"很好"or"快樂"or"不錯")in e:
    site=(YouTubeVideo('ru0K8uYEZWw'))
    display(site)
    time.sleep(1)
    print('更多歌曲請前往：https://www.youtube.com/playlist?list=PLW9z2i0xwq0F3-8LieqflLLWLWZQgvhEX')
elif("不好")or("不太好")or("糟透了")or("很差")or("崩潰")or("憂鬱")or("絕望")in e:
    site=(YouTubeVideo('o9oy05nc9oM'))
    display(site)
    time.sleep(1)
    print('更多歌曲請前往：https://www.youtube.com/playlist?list=PL5D7fjEEs5yflZzSZAhxfgQmN6C_6UJ1W')
# Out:
# 今天心情如何？爛透了
# 更多歌曲請前往：https://www.youtube.com/playlist?list=PL5D7fjEEs5yflZzSZAhxfgQmN6C_6UJ1W

# %% [markdown]
# # ▴目前無法直接匯入YouTube的播放清單＆print出超連結
